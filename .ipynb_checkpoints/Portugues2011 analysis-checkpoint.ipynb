# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from utilities import *

from matplotlib import pyplot as plt
# %matplotlib notebook
import seaborn as sns
sns.set(style="ticks", palette="deep")
cols = sns.color_palette()
plt.style.use('v_arial')

# %%
master_path = Path(r'J:\_Shared\stytra\manuscript\datasets\portugues_2011')
paths = list(master_path.glob('*f*'))
paths
# Out:
# [WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f0_cos'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f0_hel'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f0_kat'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f1_cos'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f1_kat'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f2_cos'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f2_hel'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f3_cos'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f3_hel'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f3_kat'),
#  WindowsPath('J:/_Shared/stytra/manuscript/datasets/portugues_2011/180919_f4_cos'),
# ...

# %%
exps = [Experiment(path) for path in paths]

# %%
exps[0]
# Out:
# {'animal': {'age': 7,
#   'comments': '',
#   'dish_diameter': '',
#   'embedded': True,
#   'genotype': 'TL',
#   'id': 0,
#   'screened': 'not',
#   'species': 'Danio Rerio',
#   'treatment': ''},
#  'behavior': {'estimator_log': '133952_estimator_log.hdf5',
#   'log': '133952_log.hdf5',
#   'prefiltering': {'color_invert': False,
#    'display_processed': 'raw',
#    'filter_size': 6,
#    'image_scale': 1.0},
#   'tail_params': {'dark_tail': True,
#    'n_segments': 8,
#    'tail_length': [-16.884149603636615, -358.52641732727216],
#    'tail_start': [551.4264442146139, 814.3872443983525]}},
#  'behaviour': {},
#  'camera': {'params': {'exposure': 1.0, 'framerate': 223.0, 'gain': 1.0}},
#  'general': {'db_index': -1,
#   'experimenter_name': 'Elena Dragomir',
#   'session_id': 0,
#   'setup_name': '2p',
#   't_protocol_end': '2018-09-19T14:34:24.718916',
#   't_protocol_start': '2018-09-19T13:39:53.635841'},
#  'imaging': {},
# ...

# %%
plt.figure(figsize=(10,25))
n_subplots = len(exps)
[]
for i in range(len(exps)):
    exp = exps[i]
    if not exp.exclude:
        plt.subplot(n_subplots//4 + 1, 4, i+1)
        mat = np.zeros(int(109*30/0.01))
        mat[:len(exp.df['bin_swim'])] = exp.df['bin_swim'].as_matrix()[:len(mat)]
        mat = mat.reshape(109, int(30/0.01))
        plt.imshow(-mat[:,750:2250], aspect='auto')
        plt.title('{}_{}'.format(exp.path.parts[-2].split('_')[-1], exp.path.parts[-1]))
        plt.xticks([])
        plt.yticks([])
    
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
print(['{}_{}'.format(e.path.parts[-2].split('_')[-1], e.path.parts[-1]) for e in exps])
# Out:
# ['cos1_180919_f0', 'cos1_180919_f1', 'cos1_180919_f2', 'cos1_180919_f3', 'cos1_180919_f4', 'cos1_180919_f5', 'cos1_180920_f0', 'cos1_180920_f1', 'cos1_180920_f2', 'cos1_180920_f3', 'cos1_180920_f4', 'cos1_180920_f5', 'cos1_180920_f6', 'hel_180919_f0', 'hel_180919_f1', 'hel_180919_f2', 'hel_180919_f3', 'hel_180919_f4', 'hel_180920_f0', 'hel_180920_f1', 'hel_180920_f2', 'hel_180920_f3', 'hel_180920_f4', 'hel_180920_f5', 'hel_180920_f6', 'hel_180920_f7', 'kat_180919_f0', 'kat_180919_f1', 'kat_180919_f2', 'kat_180919_f3', 'kat_180919_f4', 'kat_180919_f5', 'kat_180920_f0', 'kat_180920_f1', 'kat_180920_f2', 'kat_180920_f3', 'kat_180920_f4', 'kat_180920_f5', 'kat_180920_f6']

# %%
'hel_180920_f7', 'hel_180920_f2', 'hel_180920_f1', 'hel_180920_f0', 'hel_180919_f1', 'hel_180919_f1'
'cos1_180919_f5', 'cos1_180920_f4', 'cos1_180919_f5', 'cos1_180920_f3', 'cos1_180920_f4', 'cos1_180920_f0',
'kat_180920_f2', 'kat_180920_f1', 'kat_180919_f2', 'kat_180920_f6', 'kat_180920_f0', 'kat_180920_f4'

# %%
no_way = ['hel_180920_f7', 'hel_180920_f2', 'hel_180920_f1']
so_und_so = no_way +  ['hel_180920_f0', 'hel_180919_f1', 'hel_180919_f1',
                       'cos1_180919_f5', 'cos1_180920_f4', 'cos1_180919_f5', 'cos1_180920_f3', 'cos1_180920_f4', 'cos1_180920_f0',
                       'kat_180920_f2', 'kat_180920_f1', 'kat_180919_f2', 'kat_180920_f6', 'kat_180920_f0',
                      'kat_180920_f4']
for e in exps:
    e.exclude = '{}_{}'.format(e.path.parts[-2].split('_')[-1], e.path.parts[-1]) in so_und_so

# %%
print(['{}_{}'.format(e.path.parts[-2], e.path.parts[-1]) for e in exps])
# Out:
# ['180919_cos1_180919_f0', '180919_cos1_180919_f1', '180919_cos1_180919_f2', '180919_cos1_180919_f3', '180919_cos1_180919_f4', '180919_cos1_180919_f5', '180919_cos1_180920_f0', '180919_cos1_180920_f1', '180919_cos1_180920_f2', '180919_hel_180919_f0', '180919_hel_180919_f1', '180919_hel_180919_f2', '180919_hel_180919_f3', '180919_hel_180919_f4', '180919_hel_180920_f0', '180919_hel_180920_f1', '180919_hel_180920_f2', '180919_kat_180919_f0', '180919_kat_180919_f1', '180919_kat_180919_f2', '180919_kat_180919_f3', '180919_kat_180919_f4', '180919_kat_180919_f5', '180919_kat_180920_f0', '180919_kat_180920_f1', '180919_kat_180920_f2']

# %%
exps[0].exp_stats.keys()
# Out:
# Index(['gains', 'interbout_t', 'latency_to_first', 'mean_bout_len', 'n_bouts',
#        't_end', 't_start'],
#       dtype='object')

# %%
def back_color():
    plt.axvspan(-0.5, 2.5, color=(0.9,)*3)
    plt.axvspan(8.5, 11.5, color=(0.9,)*3)
    plt.axvspan(5.5, 8.5, color=(0.7,)*3)
    plt.axvspan(11.5, 14.5, color=(0.7,)*3)
    
def cum_stat(key):
    stat = np.array([np.nanmean(exp.exp_stats[key].as_matrix()[1:].reshape(6, 18), 0) for exp in exps if not exp.exclude]).T
    stat = stat/np.nanmean(stat[:3,:], 0)
    return stat

# %%
stat.shape
# Out:
# (18, 24)

# %%
plt.figure(figsize = (8,8))
plt.subplot(2,2,1)
k = 'mean_bout_len'
stat = cum_stat(k)
plt.errorbar(np.arange(stat.shape[0]), np.nanmean(stat, 1), np.nanstd(stat, 1)/np.sqrt(stat.shape[1]-1))
plt.plot(stat, linewidth = 0.1, c='k')
back_color()
plt.ylim(0.7,1.4)

plt.subplot(2,2,2)
k = 'interbout_t'
stat = cum_stat(k)
plt.errorbar(np.arange(stat.shape[0]), np.nanmean(stat, 1), np.nanstd(stat, 1)/np.sqrt(stat.shape[1]-1))
plt.plot(stat, linewidth = 0.1, c='k')
back_color()
plt.ylim(0.5,1.5)

plt.subplot(2,2,3)
k = 'n_bouts'
stat = cum_stat(k)
plt.errorbar(np.arange(stat.shape[0]), np.nanmean(stat, 1), np.nanstd(stat, 1)/np.sqrt(stat.shape[1]-1))
plt.plot(stat, linewidth = 0.1, c='k')
back_color()
plt.ylim(0.5,1.5)

plt.subplot(2,2,4)
k = 'latency_to_first'
stat = cum_stat(k)
plt.errorbar(np.arange(stat.shape[0]), np.nanmean(stat, 1), np.nanstd(stat, 1)/np.sqrt(stat.shape[1]-1))
plt.plot(stat, linewidth = 0.1, c='k')
back_color()
plt.ylim(0.7,1.4)
# Out:
# <img src="data:image/png;base64,..." width="800">
# C:\Users\lpetrucco\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: Mean of empty slice
# (0.7, 1.4)

# %%
final_fig = plt.figure()
k = 'interbout_t'
stat = cum_stat(k)
plt.errorbar(np.arange(stat.shape[0]), np.nanmean(stat, 1), np.nanstd(stat, 1)/np.sqrt(stat.shape[1]-1))
plt.plot(stat, linewidth = 0.1, c='k')
back_color()
plt.ylim(0.5,1.5)
plt.xlim((-0.5, 17.5))
plt.xticks(np.arange(1, 17, 3), np.arange(2, 18, 3))
plt.ylabel('relative duration')
plt.xlabel('trial number')
# Out:
# <img src="data:image/png;base64,..." width="640">
# C:\Users\lpetrucco\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:8: RuntimeWarning: Mean of empty slice

# %%
import matplotlib
matplotlib.rc('pdf', fonttype=42)
final_fig.savefig('final_interbout_t_plot.pdf', format='pdf')

# %%
plt.figure()
i = 0
plt.plot(exps[i]['dynamic_log']['t'], exps[i]['dynamic_log']['closed loop 1D_gain'])
# Out:
# <img src="data:image/png;base64,..." width="704">

# %%
e = exps[21]

# %%
plt.figure()
plt.plot(e.df['tail_sum'][:])
plt.plot(e.df['bin_swim'][:])
plt.plot(e.df['closed loop 1D_gain'][:])
plt.plot(e.df['closed loop 1D_vel'][:])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
e.bouts
# Out:
# array([[4.40000e-01, 7.30000e-01],
#        [1.74000e+00, 2.00000e+00],
#        [1.17300e+01, 1.20500e+01],
#        ...,
#        [3.25774e+03, 3.25806e+03],
#        [3.25864e+03, 3.25900e+03],
#        [3.25951e+03, 3.25987e+03]])

# %%
e.exp_stats
# Out:
#      gains  interbout_t  latency_to_first  mean_bout_len  n_bouts  t_end  \
# 0      1.0     0.463000              1.73       0.346364       11     20
# 1      1.0     0.462222              1.56       0.408000       10     50
# 2      1.0     0.424000              2.08       0.340000       11     80
# 3      1.0     0.491111              0.98       0.428000       10    110
# 4      1.5     0.491429              3.36       0.368750        8    140
# 5      1.5     0.550000              2.21       0.410000        9    170
# 6      1.5     0.561429              2.26       0.433750        8    200
# 7      0.5     0.444286              1.46       0.386250        8    230
# 8      0.5     0.361538              0.84       0.319286       14    260
# 9      0.5          NaN              9.17       0.010000        1    290
# 10     1.0     0.400909              0.52       0.397500       12    320
# 11     1.0     0.398182              0.47       0.402500       12    350
# ...
